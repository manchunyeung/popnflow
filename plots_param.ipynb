# %% [markdown]
# ### The first plot extended the priors of alpha, beta = [-8,2]; mmin = [0,10], mmax = [30,100]

# %%
import emcee
filename = "extended_prior.txt"
backend = emcee.backends.HDFBackend(filename) 
flat_samples = backend.get_chain(discard=100, thin=100, flat=True)

# %%
import corner

labels = ['alpha', 'beta', 'mmin', 'mmax']

fig = corner.corner(
    flat_samples, labels=labels, smooth=1.2
);

# %% [markdown]
# ### The second plot here is using priors from GWTC 1 paper. alpha, beta = [-4, 12]; mmin = [5, 10], mmax = [30, 100]

# %%
filename = "standard_prior.txt"
backend = emcee.backends.HDFBackend(filename) 
flat_samples = backend.get_chain(discard=100, thin=100, flat=True)

# %%
import corner

labels = ['alpha', 'beta', 'mmin', 'mmax']

fig = corner.corner(
    flat_samples, labels=labels, smooth=1.2
);

# %% [markdown]
# ### Extreme case, extending prior to [-20, -5]

# %%
import emcee
filename = "extendedd_prior.txt"
backend = emcee.backends.HDFBackend(filename) 
flat_samples = backend.get_chain(discard=100, thin=100, flat=True)
labels = ['alpha', 'beta', 'mmin', 'mmax']

fig = corner.corner(
    flat_samples, labels=labels, smooth=1.2
);
