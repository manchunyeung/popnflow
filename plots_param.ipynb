# %% [markdown]
# ### The first plot here is showing -3<alpha<4, -4<beta<12, 9<kappa<17

# %%
import emcee
filename = "stored_walkers.txt"
backend = emcee.backends.HDFBackend(filename) 
flat_samples = backend.get_chain(discard=100, thin=100, flat=True)

# %%
import corner

labels = ['alpha', 'beta', 'kappa', 'mmin', 'mmax']

fig = corner.corner(
    flat_samples, labels=labels, smooth=1.2
);
# Out:
# /opt/conda/igwn-py310-20231120/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### The second plot here showing 0<alpha<4, 0<beta<12, 0<kappa<14

# %%
filename = "stored_walkers1.txt"
backend = emcee.backends.HDFBackend(filename) 
flat_samples = backend.get_chain(discard=100, thin=100, flat=True)

# %%
import corner

labels = ['alpha', 'beta', 'kappa', 'mmin', 'mmax']

fig = corner.corner(
    flat_samples, labels=labels, smooth=1.2
);
# Out:
# WARNING:root:Too few points to create valid contours
