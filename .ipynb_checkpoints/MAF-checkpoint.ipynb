# %% [markdown]
# # Using denamrf to estimate posteriors of GW150914

# %%
# Installing denamrf 
# !pip install getdist denmarf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: getdist in /home/manchun.yeung/.local/lib/python3.9/site-packages (1.4.7)
# Requirement already satisfied: denmarf in /home/manchun.yeung/.local/lib/python3.9/site-packages (0.3.2)
# Requirement already satisfied: packaging in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from getdist) (21.3)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from getdist) (1.23.2)
# Requirement already satisfied: matplotlib!=3.5.0,>=2.2.0 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from getdist) (3.5.3)
# Requirement already satisfied: scipy>=1.5 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from getdist) (1.8.1)
# Requirement already satisfied: PyYAML>=5.1 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from getdist) (5.4.1)
# Requirement already satisfied: tqdm in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from denmarf) (4.64.1)
# Requirement already satisfied: torch in /home/manchun.yeung/.local/lib/python3.9/site-packages (from denmarf) (2.1.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (4.37.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (11.0.2.54)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (2.18.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (12.1.105)
# Requirement already satisfied: networkx in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (2.1.0)
# Requirement already satisfied: jinja2 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from torch->denmarf) (3.1.2)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (10.3.2.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (12.1.105)
# Requirement already satisfied: typing-extensions in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from torch->denmarf) (4.3.0)
# Requirement already satisfied: filelock in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (3.13.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (8.9.2.26)
# Requirement already satisfied: sympy in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (1.12)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from torch->denmarf) (12.1.105)
# Requirement already satisfied: fsspec in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from torch->denmarf) (2022.8.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->denmarf) (12.3.101)
# Requirement already satisfied: six>=1.5 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.5.0,>=2.2.0->getdist) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda3-2022-11-29/lib/python3.9/site-packages (from jinja2->torch->denmarf) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/manchun.yeung/.local/lib/python3.9/site-packages (from sympy->torch->denmarf) (1.3.0)

# %%
# Import libraries

import numpy as np
from scipy.stats import multivariate_normal
from denmarf import DensityEstimate

# Plotting
import matplotlib
from matplotlib import pyplot as plt
import getdist
from getdist import MCSamples, plots
# %matplotlib inline
# %config InlineBackend.figure_format="retina"

# %%
# #Import data from ligo
# !wget https://dcc.ligo.org/public/0157/P1800370/002/GWTC-1_sample_release.tar.gz
# !tar -xvzf GWTC-1_sample_release.tar.gz

# %%
# %matplotlib inline

import h5py

import pandas as pd
from scipy.interpolate import interp1d
from astropy import cosmology, units

import bilby as bb
from bilby.core.prior import LogUniform, PriorDict, Uniform
from bilby.hyper.model import Model
import gwpopulation as gwpop

# %%
parameter_translator = dict(
    mass_1_det="m1_detector_frame_Msun",
    mass_2_det="m2_detector_frame_Msun",
    luminosity_distance="luminosity_distance_Mpc",
    a_1="spin1",
    a_2="spin2",
    cos_tilt_1="costilt1",
    cos_tilt_2="costilt2",
)

posteriors = list()
priors = list()

file_str = "./GWTC-1_sample_release/GW{}_GWTC-1.hdf5"

events = [
    "150914",
    "151012",
    "151226",
    "170104",
    "170608",
    "170729",
    "170809",
    "170814",
    "170818",
    "170823",
]
for event in events:
    _posterior = pd.DataFrame()
    _prior = pd.DataFrame()
    with h5py.File(file_str.format(event)) as ff:
        for my_key, gwtc_key in parameter_translator.items():
            _posterior[my_key] = ff["IMRPhenomPv2_posterior"][gwtc_key]
            _prior[my_key] = ff["prior"][gwtc_key]
    posteriors.append(_posterior)
    priors.append(_prior)

# %%
posteriors[0]
# Out:
#        mass_1_det  mass_2_det  luminosity_distance       a_1       a_2  \
# 0       43.561878   30.006974           360.963036  0.481479  0.551643
# 1       37.006684   35.723611           538.067256  0.323226  0.225597
# 2       35.747480   34.267309           378.730720  0.490409  0.229346
# 3       45.168491   26.692544           446.937909  0.907815  0.128135
# 4       36.308165   35.889917           496.628291  0.144858  0.437158
# ...           ...         ...                  ...       ...       ...
# 40831   38.577778   31.417375           503.472940  0.268453  0.194847
# 40832   37.253314   33.156328           478.421089  0.805262  0.823590
# 40833   40.528821   30.134671           516.916074  0.437801  0.408049
# 40834   35.683458   34.021918           464.564783  0.214438  0.819591
# 40835   37.076340   34.457461           460.556753  0.325657  0.517163
#
#        cos_tilt_1  cos_tilt_2
# 0        0.012162    0.137818
# 1        0.454174   -0.482123
# 2       -0.069300   -0.493216
# 3       -0.127557   -0.694896
# 4        0.487946   -0.237507
# ...           ...         ...
# 40831    0.039890   -0.925528
# 40832    0.655502   -0.985068
# 40833   -0.277677   -0.280263
# 40834   -0.557688   -0.119711
# 40835   -0.289037    0.054623
#
# [40836 rows x 7 columns]

# %%
# Samples from the first three parameters
first_event = posteriors[0]

parameters = np.array([first_event['mass_1_det'].values, first_event['mass_2_det'].values, first_event['luminosity_distance'].values])
parameters = parameters.transpose()

# %%
lower_bounds = np.full(np.asarray(parameters).shape, [5,5,100])
upper_bounds = np.full(np.asarray(parameters).shape, [60,60,700])

# %%
de = DensityEstimate.from_file(filename="data/denmarf_bounded256.pkl")

# # Denmarf density estimation
# de = DensityEstimate(device="cuda:2", use_cuda=True).fit(
#     parameters,
#     num_blocks=32,
#     num_hidden=5,
#     num_epochs=100,
#     bounded=True,
#     lower_bounds = lower_bounds,
#     upper_bounds = upper_bounds
# )
# de.save("first_event_denmarf.pkl")

# %%
# True data for evaluation, using the remaining 30% of data
parameters_eval = list()

training_index = int(len(first_event['mass_1_det'])*0.7)

for i in range(training_index, len(first_event['mass_1_det'])):
    parameters_eval.append([first_event['mass_1_det'][i], first_event['mass_2_det'][i], first_event['luminosity_distance'][i]])
    
parameters_eval = np.array(parameters_eval)

# %%
samples_exact = MCSamples(samples=parameters_eval, label="from samples")

xgen_maf = de.sample(40836)
samples_maf = MCSamples(samples=xgen_maf, label="from denmarf")
g1 = plots.get_subplot_plotter()
g1.triangle_plot([samples_exact, samples_maf], filled=False)
# Out:
# Removed no burn in
# Removed no burn in

# %%
de = DensityEstimate.from_file(filename="data/denmarf_blocks64.pkl")
xgen_maf = de.sample(12000)
samples_maf = MCSamples(samples=xgen_maf, label="from denmarf")
g2 = plots.get_subplot_plotter()
g2.triangle_plot([samples_exact, samples_maf], filled=False)
# Out:
# Removed no burn in

# %%
lower_bounds.shape
# Out:
# (40836, 3)
