# %%
# !pip install wand
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 19.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Comparing different num_blocks

# %%
from wand.image import Image as WImage
img = WImage(filename='plots/maf_32_10_200.pdf')
img
# Out:
# <wand.image.Image: e45e422 'PDF' (424x423)>

# %%
img = WImage(filename='plots/maf_64_10_200.pdf')
img
# Out:
# <wand.image.Image: de9e839 'PDF' (424x423)>

# %%
img = WImage(filename='plots/maf_128_10_200.pdf')
img
# Out:
# <wand.image.Image: aa7b7d3 'PDF' (424x423)>

# %%
img = WImage(filename='plots/maf_256_10_200.pdf')
img
# Out:
# <wand.image.Image: 44e5763 'PDF' (424x423)>

# %% [markdown]
# #### Conclusion: seems 64 is the best

# %% [markdown]
# ### Varying num_hidden for num_blocks = 32 and 64

# %%
# num_blocks = 64 here
img = WImage(filename='plots/maf_64_5_200.pdf')
img
# Out:
# <wand.image.Image: a3c055e 'PDF' (424x423)>

# %%
img = WImage(filename='plots/maf_64_10_200.pdf')
img
# Out:
# <wand.image.Image: de9e839 'PDF' (424x423)>

# %%
img = WImage(filename='plots/maf_64_15_200.pdf')
img
# Out:
# <wand.image.Image: 29e1435 'PDF' (424x423)>

# %%
# num_blocks = 32
img = WImage(filename='plots/maf_32_5_200.pdf')
img
# Out:
# <wand.image.Image: 8964689 'PDF' (424x423)>

# %%
# num_blocks = 32
img = WImage(filename='plots/maf_32_10_200.pdf')
img
# Out:
# <wand.image.Image: e45e422 'PDF' (424x423)>

# %%
# num_blocks = 32
img = WImage(filename='plots/maf_32_15_200.pdf')
img
# Out:
# <wand.image.Image: 8ed2d75 'PDF' (424x423)>

# %% [markdown]
# #### Hard to say, seems num_hidden = 10 is better

# %% [markdown]
# ### Is increasing epochs better?

# %%
# num_blocks = 32
img = WImage(filename='plots/maf_128_10_100.pdf')
img
# Out:
# <wand.image.Image: 06da206 'PDF' (424x423)>

# %%
# num_blocks = 32
img = WImage(filename='plots/maf_128_10_200.pdf')
img
# Out:
# <wand.image.Image: aa7b7d3 'PDF' (424x423)>

# %%
# num_blocks = 32
img = WImage(filename='plots/maf_128_10_300.pdf')
img
# Out:
# <wand.image.Image: 634f2f1 'PDF' (430x423)>

# %% [markdown]
# #### No improvement
